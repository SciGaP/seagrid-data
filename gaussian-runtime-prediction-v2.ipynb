# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.cross_validation import cross_val_predict

# %%
#loading csv file
df = pd.read_csv('gaussian-runtime-v2.csv')

# %%
df = df[(df.fopt != 0) | (df.freq != 0) | (df.fts != 0) | (df.popt != 0) | (df.sp != 0)]
df = df[(df.machine != 0) & (df.memory != 0) & (df.nproc != 0)]
# jobs with runtime greater than 8 hours are long jobs
df['long_job'] = df.runtime > 28800
df['long_job'] = df.long_job.astype(int)
df = df.drop('runtime', 1)
df = df.drop('id', 1)

# %%
df
# Out:
#       fopt  freq  fts  machine  memory  natoms  nbasis  nproc  popt  sp  \
# 0        1     1    0        1    1000       7     290     16     0   0
# 1        1     0    0        3    8000      37     360      4     0   0
# 2        1     1    0        3    8000      53     355     16     0   0
# 4        1     1    0        1    8000      64     609     16     0   0
# 5        0     0    0        2    8000      49     488     16     0   1
# 6        1     1    0        3    8000      52     585     16     0   0
# 7        0     0    0        3    8000      41     433     16     0   1
# 8        1     1    0        3    1000       5     168     16     0   0
# 9        1     1    0        3    8000      96     712     16     0   0
# 10       1     1    0        3    1000       3     136     16     0   0
# 11       0     0    0        1    8000      43     437     16     0   7
# 12       0     0    0        3    8000      41     433     16     0   1
# 13       1     0    0        3    8000      37     360      4     0   0
# 14       1     0    0        3    8000      46     460     16     0   0
# 15       1     1    0        1    1000       3      36     16     0   0
# 16       0     0    0        3    1000      25     416     16     0   1
# 17       1     1    0        3    8000      55     369     16     0   0
# 18       1     1    0        3    1000      24     221     16     0   0
# 19       1     0    0        3    8000      40     422     16     0   0
# 20       0     1    0        3    1000      44     387     16     0   0
# 21       1     0    0        3    2000       5     300     16     0   0
# 22       1     1    0        1   20000      54     558     12     0   0
# 23       0     0    0        1    2000       6     412     16     0   1
# 24       0     0    0        3    8000      41     433     16     0   1
# 25       1     1    0        3   16000      51     590     16     0   0
# 26       1     0    0        3    8000      41     441     16     0   0
# 27       1     1    0        3   16000      39     483     16     0   0
# 28       1     1    0        3    1000       3      92     16     0   0
# 30       0     1    1        3    1000      24     221     16     0   0
# 32       1     1    0        3    8000      11     144     16     0   0
# ...    ...   ...  ...      ...     ...     ...     ...    ...   ...  ..
# 4614     1     0    0        3    8000      66     652     16     0   0
# 4615     1     1    0        3    1000       5     212     16     0   0
# 4616     0     0    0        3    1000       3      92     16     0   1
# 4617     1     1    0        3    1000      24     217     16     0   0
# 4618     0     0    0        3    8000      41     433     16     0   1
# 4619     0     2    0        3    8000      55     369     16     0   0
# 4620     1     1    0        1    8000      64     609     16     0   0
# 4621     1     0    0        3    8000      43     519     16     0   0
# 4622     1     1    0        3    9000     140    1060     16     0   0
# 4624     1     0    0        3    1000       7     281     16     0   0
# 4625     0     1    0        1    5000       5     400     16     0   0
# 4626     0     0    0        3    8000      41     433     16     0   1
# 4627     0     0    0        3    8000      41     433     16     0   1
# 4628     1     1    0        1   16000      14     222     16     0   0
# 4629     1     1    0        3    8000      55     526     16     0   0
# 4630     0     1    1        3    1000      30     259     16     0   0
# 4631     1     0    0        3    8000      51     648     16     0   0
# 4632     1     1    0        3    8000      46     540     16     0   0
# 4633     1     0    0        3    8000      53     526     16     0   0
# 4634     1     1    0        3   16000      51     590     16     0   0
# 4635     1     0    0        2    1000      43     346     16     0   0
# 4636     0     0    0        3    1000      30     259     16     0   1
# 4637     1     0    0        1    5000       6     276     16     0   0
# 4638     1     1    0        1    8000      84     844     16     0   0
# 4639     1     0    0        3    7500      46     460      4     0   0
# 4640     0     0    0        2    8000      76     810     16     0   1
# 4641     1     1    0        3    1000       5     256     16     0   0
# 4642     0     1    0        3    8000     121    1315     16     0   0
# 4643    10     0    0        1    8000      43     437     16     0   0
# 4645     1     0    0        3   12000      55     565     16     0   0
#
#       long_job
# 0            0
# 1            1
# 2            1
# 4            1
# 5            0
# 6            1
# 7            0
# 8            0
# 9            0
# 10           0
# 11           1
# 12           0
# 13           1
# 14           1
# 15           0
# 16           0
# 17           1
# 18           0
# 19           1
# 20           0
# 21           0
# 22           1
# 23           1
# 24           0
# 25           1
# 26           1
# 27           1
# 28           0
# 30           0
# 32           0
# ...        ...
# 4614         1
# 4615         0
# 4616         0
# 4617         0
# 4618         0
# 4619         1
# 4620         1
# 4621         1
# 4622         1
# 4624         0
# 4625         1
# 4626         0
# 4627         0
# 4628         1
# 4629         0
# 4630         0
# 4631         1
# 4632         0
# 4633         1
# 4634         1
# 4635         0
# 4636         0
# 4637         1
# 4638         1
# 4639         1
# 4640         0
# 4641         0
# 4642         1
# 4643         1
# 4645         0
#
# [4418 rows x 11 columns]
